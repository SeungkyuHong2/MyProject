# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/Seung kyu Hong/Desktop/final.csv')

# %%
data['Date'] = pd.to_datetime(data['Date'],format='%Y-%m-%d')

# %%
for column in data.columns:
    try:
        data.plot('Date',column, kind='line',figsize=(10,10))
    except:
        pass
# Out:
# C:\Users\Seung kyu Hong\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
data.drop(['qurrate'],axis=1,inplace=True)

# %%
for column in a:
    try:
        data[column] = abs(data[column]-data[column].mean())/np.std(data[column])
    except:
        pass

# %%
data.to_csv('final.csv',index=False)

# %%
a = ['Floating_Population', 'Subway_Usage', 'TCS_in', 'TCS_out', 'Seoul_Car',
       'Domestic_Air_Seoul_Out', 'Domestic_Air_Seoul_In', 'trendto12',
       'trend13to18', 'trend19to24', 'trend25to29', 'trend30to34',
       'trend35to39', 'trend40to44', 'trend45to49', 'trend50to54',
       'trend55to59', 'trendOver60', 'trendTotal']

# %%
a = []
a.append(1)
for i in range(1,len(data)):
    a.append(data.loc[i,'Cleared']-data.loc[i-1,'Cleared'])

# %%
data
# Out:
#           Date  Daily_Confirmed  Cleared  traveled  Total_Confirmed  \
# 0   2020-03-01                6        1         0             3736
# 1   2020-03-02                6        1         0             4212
# 2   2020-03-03                1        1         0             4812
# 3   2020-03-04                5        2         1             5328
# 4   2020-03-05                1        2         0             5766
# 5   2020-03-06                7        2         0             6284
# 6   2020-03-07                7        3         1             6767
# 7   2020-03-08                9        3         0             7134
# 8   2020-03-09               10        3         1             7382
# 9   2020-03-10               11        2         1             7513
# 10  2020-03-11               52        6         1             7755
# 11  2020-03-12               19        1         3             7869
# 12  2020-03-13               13        2         2             7979
# ...

# %%
a.pop()
# Out:
# nan

# %%
a.insert(0,1)

# %%
len(a)
# Out:
# 245

# %%
a = pd.DataFrame(a)

# %%
a.to_csv('a.csv',index=False)

# %%
len(a)
# Out:
# 246

# %%
len(data['Cleared'])
# Out:
# 246

# %%
data.loc[245,'Cleared']
# Out:
# nan

# %%
data['Cleared']=a

# %%
data.head()
# Out:
#         Date  Daily_Confirmed  Cleared  qurrate  traveled  Total_Confirmed  \
# 0 2020-03-01              6.0     12.0     1.04       0.0           3736.0
# 1 2020-03-02              6.0     13.0     1.08       0.0           4212.0
# 2 2020-03-03              1.0     14.0     1.12       0.0           4812.0
# 3 2020-03-04              5.0     16.0     1.14       1.0           5328.0
# 4 2020-03-05              1.0     18.0     1.19       0.0           5766.0
#
#    Floating_Population  Subway_Usage     TCS_in    TCS_out  Seoul_Car  \
# 0          58133115.81     3745292.0  2309432.0  2307211.0  6148809.0
# 1          73462705.24    10099782.0  3466639.0  3488106.0  9107753.0
# 2          72156331.67    10101907.0  3438721.0  3480529.0  9301913.0
# 3          73844703.17    10066585.0  3427085.0  3469083.0  9397028.0
# 4          72234978.15    10126553.0  3488235.0  3530897.0  9545413.0
#
#    Domestic_Air_Seoul_Out  Domestic_Air_Seoul_In
# ...

# %%
data.to_csv('test2.csv',index=False)

# %%
data.loc[244,'Cleared']
# Out:
# 5495.0

# %%
for column in data.columns:
    try:
        print(data[column].describe())
        print('\n')
    except:
        pass
# Out:
# count                     245
# unique                    245
# top       2020-03-13 00:00:00
# freq                        1
# first     2020-03-01 00:00:00
# last      2020-10-31 00:00:00
# Name: Date, dtype: object
#
#
# count    245.000000
# mean      24.216327
# std       32.064327
# min        0.000000
# 25%        6.000000
# 50%       13.000000
# 75%       24.000000
# max      154.000000
# Name: Daily_Confirmed, dtype: float64
#
#
# count    245.000000
# mean      22.383673
# std       37.198842
# min       -1.000000
# 25%        4.000000
# 50%       10.000000
# 75%       20.000000
# max      234.000000
# Name: Cleared, dtype: float64
#
#
# count    245.000000
# mean      21.611265
# std       19.699368
# min        1.040000
# 25%        6.510000
# 50%       13.570000
# 75%       39.730000
# max       61.760000
# Name: qurrate, dtype: float64
#
#
# count    245.000000
# mean       1.865306
# std        2.756925
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# ...

# %%
data.describe()
# Out:
#        Daily_Confirmed     Cleared     qurrate    traveled  Total_Confirmed  \
# count       245.000000  245.000000  245.000000  245.000000       245.000000
# mean         24.216327   22.383673   21.611265    1.865306     14831.102041
# std          32.064327   37.198842   19.699368    2.756925      5735.046759
# min           0.000000   -1.000000    1.040000    0.000000      3736.000000
# 25%           6.000000    4.000000    6.510000    0.000000     10774.000000
# 50%          13.000000   10.000000   13.570000    1.000000     12850.000000
# 75%          24.000000   20.000000   39.730000    2.000000     19947.000000
# max         154.000000  234.000000   61.760000   14.000000     26511.000000
#
#        Floating_Population  Subway_Usage        TCS_in       TCS_out  \
# count         2.140000e+02  2.140000e+02  2.450000e+02  2.450000e+02
# mean          7.137883e+07  1.034542e+07  3.989412e+06  4.040731e+06
# std           6.189491e+06  2.860417e+06  5.092538e+05  5.147088e+05
# ...

# %%
roll7 = pd.Series.rolling(temp['Floating_Population'],window=7,center=False).mean()
roll14 = pd.Series.rolling(data['Floating_Population'],window=14,center=False).mean()
roll28 = pd.Series.rolling(data['Floating_Population'],window=28,center=False).mean()

# %%
fig = plt.figure(figsize=(12,4))

chart = fig.add_subplot(1,1,1)

chart.plot(temp['Floating_Population'],color='blue',label='Seoul_Car')
chart.plot(roll7,color='red',label='Seoul_Car_rolling7')
chart.plot(temp['Daily_Confirmed'])

plt.legend(loc='best')

# %%
roll7=roll7.dropna()

# %%
roll7.shape
# Out:
# (210,)

# %%
roll7.plot()

# %%
temp = data.copy()

# %%
temp.index = temp['Date']

# %%
temp.head()
# Out:
#                  Date  Daily_Confirmed  Cleared  qurrate  traveled  \
# Date
# 2020-03-01 2020-03-01                6        1     1.04         0
# 2020-03-02 2020-03-02                6        1     1.08         0
# 2020-03-03 2020-03-03                1        1     1.12         0
# 2020-03-04 2020-03-04                5        2     1.14         1
# 2020-03-05 2020-03-05                1        2     1.19         0
#
#             Total_Confirmed  Floating_Population  Subway_Usage   TCS_in  \
# Date
# 2020-03-01             3736          58133115.81     3745292.0  2309432
# 2020-03-02             4212          73462705.24    10099782.0  3466639
# 2020-03-03             4812          72156331.67    10101907.0  3438721
# 2020-03-04             5328          73844703.17    10066585.0  3427085
# 2020-03-05             5766          72234978.15    10126553.0  3488235
#
#             TCS_out  ...  trend19to24  trend25to29  trend30to34  trend35to39  \
# Date                 ...
# ...

# %%
roll7 = pd.Series.rolling(temp['Seoul_Car'],window=14,center=False).mean()

# %%
roll7.head()
# Out:
# Date
# 2020-03-01   NaN
# 2020-03-02   NaN
# 2020-03-03   NaN
# 2020-03-04   NaN
# 2020-03-05   NaN
# Name: Floating_Population, dtype: float64
