# %%
import firebase_admin

# %%
from firebase_admin import credentials

# %%
from google.cloud import firestore
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d43cdedc4fdd> in <module>
# ----> 1 from google.cloud import firestore
#
# ~\Anaconda3\lib\site-packages\google\cloud\firestore\__init__.py in <module>
#      27     __version__ = None
#      28
# ---> 29 from google.cloud.firestore_v1 import types
#      30 from google.cloud.firestore_v1._helpers import GeoPoint
#      31 from google.cloud.firestore_v1._helpers import ExistsOption
#
# ~\Anaconda3\lib\site-packages\google\cloud\firestore_v1\__init__.py in <module>
#      33 from google.cloud.firestore_v1._helpers import ReadAfterWriteError
#      34 from google.cloud.firestore_v1._helpers import WriteOption
# ---> 35 from google.cloud.firestore_v1.async_batch import AsyncWriteBatch
#      36 from google.cloud.firestore_v1.async_client import AsyncClient
# ...
