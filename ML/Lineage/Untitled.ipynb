# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
trade = pd.read_csv('C:/Users/studying/train_trade.csv')

# %%
trade.head()
# Out:
#    day      time  type server  source_acc_id  source_char_id  target_acc_id  \
# 0    1  21:40:09     0     bd         115641          202802          42143
# 1    1  13:08:52     1     ah         104546          293593          41270
# 2    1  21:01:48     1     au          84624          107496          33916
# 3    1  14:37:50     1     ar          78411          226143          80350
# 4    1  20:32:00     0     ay          50284           44100          17523
#
#    target_char_id item_type   item_amount  item_price
# 0          197398       etc  2.678249e-07    0.001859
# 1          224395       etc  9.373872e-06         NaN
# 2          312167     adena  2.249729e+00         NaN
# 3           34764     adena  6.695623e-03         NaN
# 4          276351       etc  5.356498e-08    0.037402

# %%
trade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2245196 entries, 0 to 2245195
# Data columns (total 11 columns):
# day               int64
# time              object
# type              int64
# server            object
# source_acc_id     int64
# source_char_id    int64
# target_acc_id     int64
# target_char_id    int64
# item_type         object
# item_amount       float64
# item_price        float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 188.4+ MB

# %%
trade.describe()
# Out:
#                 day          type  source_acc_id  source_char_id  \
# count  2.245196e+06  2.245196e+06   2.245196e+06    2.245196e+06
# mean   1.478801e+01  4.632749e-01   6.566591e+04    2.006446e+05
# std    8.076896e+00  4.986496e-01   3.773964e+04    1.147208e+05
# min    1.000000e+00  0.000000e+00   2.000000e+00    1.000000e+00
# 25%    8.000000e+00  0.000000e+00   3.334700e+04    1.015950e+05
# 50%    1.500000e+01  0.000000e+00   6.548300e+04    2.006260e+05
# 75%    2.200000e+01  1.000000e+00   9.811900e+04    3.003960e+05
# max    2.800000e+01  1.000000e+00   1.304740e+05    3.974380e+05
#
#        target_acc_id  target_char_id   item_amount    item_price
# count   2.245196e+06    2.245196e+06  2.245196e+06  1.205053e+06
# mean    6.593818e+04    2.003954e+05  1.177599e-01  1.942323e-01
# std     3.760940e+04    1.147975e+05  8.391393e-01  7.983718e-01
# min     2.000000e+00    1.000000e+00  2.678249e-08  9.350504e-08
# ...

# %%
type_0 = trade.where(trade['type']==0)

# %%
type_0.head()
# Out:
#    day      time  type server  source_acc_id  source_char_id  target_acc_id  \
# 0  1.0  21:40:09   0.0     bd       115641.0        202802.0        42143.0
# 1  NaN       NaN   NaN    NaN            NaN             NaN            NaN
# 2  NaN       NaN   NaN    NaN            NaN             NaN            NaN
# 3  NaN       NaN   NaN    NaN            NaN             NaN            NaN
# 4  1.0  20:32:00   0.0     ay        50284.0         44100.0        17523.0
#
#    target_char_id item_type   item_amount  item_price
# 0        197398.0       etc  2.678249e-07    0.001859
# 1             NaN       NaN           NaN         NaN
# 2             NaN       NaN           NaN         NaN
# 3             NaN       NaN           NaN         NaN
# 4        276351.0       etc  5.356498e-08    0.037402

# %%
type_0.dropna()
# Out:
#          day      time  type server  source_acc_id  source_char_id  \
# 0        1.0  21:40:09   0.0     bd       115641.0        202802.0
# 4        1.0  20:32:00   0.0     ay        50284.0         44100.0
# 5        1.0  00:29:02   0.0     ac        87962.0        334455.0
# 8        1.0  01:01:32   0.0     ar         5669.0         36002.0
# 9        1.0  20:20:02   0.0     aa        54445.0        383477.0
# 10       1.0  02:05:57   0.0     ab        69336.0         31464.0
# 12       1.0  19:08:28   0.0     bc        43052.0        319053.0
# 16       1.0  20:02:42   0.0     aw        85465.0        363858.0
# 18       1.0  22:48:20   0.0     ac        84252.0        296171.0
# 19       1.0  00:57:48   0.0     ae        88919.0        163122.0
# 20       1.0  19:52:35   0.0     ae        61493.0         32054.0
# 21       1.0  16:07:04   0.0     ay        60246.0        245859.0
# 23       1.0  19:21:52   0.0     au       123016.0        385775.0
# ...

# %%
type_0.dropna(inplace=True)

# %%
temp = type_0.copy()

# %%
del temp['server']

# %%
temp['item_type']
# Out:
# 0                     etc
# 4                     etc
# 5                     etc
# 8                     etc
# 9                     etc
# 10                    etc
# 12                    etc
# 16                  spell
# 18                    etc
# 19                    etc
# 20         enchant_scroll
# 21         enchant_scroll
# 23         enchant_scroll
# 25                    etc
# 26                  spell
# 30         enchant_scroll
# 31                    etc
# 32         enchant_scroll
# 37         enchant_scroll
# 39                    etc
# 47                    etc
# 50                    etc
# 52                  spell
# 53         enchant_scroll
# 58         enchant_scroll
# 59                    etc
# 60                    etc
# 61                    etc
# 62         enchant_scroll
# 63         enchant_scroll
#                 ...
# 2245157               etc
# 2245159               etc
# 2245160               etc
# 2245161               etc
# ...

# %%
temp.where(temp['item_type']=='adena')
# Out:
#          day time  type  source_acc_id  source_char_id  target_acc_id  \
# 0        NaN  NaN   NaN            NaN             NaN            NaN
# 4        NaN  NaN   NaN            NaN             NaN            NaN
# 5        NaN  NaN   NaN            NaN             NaN            NaN
# 8        NaN  NaN   NaN            NaN             NaN            NaN
# 9        NaN  NaN   NaN            NaN             NaN            NaN
# 10       NaN  NaN   NaN            NaN             NaN            NaN
# 12       NaN  NaN   NaN            NaN             NaN            NaN
# 16       NaN  NaN   NaN            NaN             NaN            NaN
# 18       NaN  NaN   NaN            NaN             NaN            NaN
# 19       NaN  NaN   NaN            NaN             NaN            NaN
# 20       NaN  NaN   NaN            NaN             NaN            NaN
# 21       NaN  NaN   NaN            NaN             NaN            NaN
# ...

# %%
temp.head()
# Out:
#    day      time  type  source_acc_id  source_char_id  target_acc_id  \
# 0  1.0  21:40:09   0.0       115641.0        202802.0        42143.0
# 4  1.0  20:32:00   0.0        50284.0         44100.0        17523.0
# 5  1.0  00:29:02   0.0        87962.0        334455.0        89597.0
# 8  1.0  01:01:32   0.0         5669.0         36002.0        80878.0
# 9  1.0  20:20:02   0.0        54445.0        383477.0        97930.0
#
#    target_char_id item_type   item_amount  item_price
# 0        197398.0       etc  2.678249e-07    0.001859
# 4        276351.0       etc  5.356498e-08    0.037402
# 5        321617.0       etc  2.678249e-05    0.031698
# 8        331947.0       etc  2.678249e-07    0.000103
# 9        197911.0       etc  1.339125e-05    0.013231

# %%
temp['item_type'].value_counts()
# Out:
# etc               759558
# enchant_scroll    285052
# armor              88025
# spell              32481
# accessory          23923
# weapon             16014
# Name: item_type, dtype: int64

# %%
temp.index = range(len(temp))

# %%
temp.head()
# Out:
#    day      time  type  source_acc_id  source_char_id  target_acc_id  \
# 0  1.0  21:40:09   0.0       115641.0        202802.0        42143.0
# 1  1.0  20:32:00   0.0        50284.0         44100.0        17523.0
# 2  1.0  00:29:02   0.0        87962.0        334455.0        89597.0
# 3  1.0  01:01:32   0.0         5669.0         36002.0        80878.0
# 4  1.0  20:20:02   0.0        54445.0        383477.0        97930.0
#
#    target_char_id item_type   item_amount  item_price
# 0        197398.0       etc  2.678249e-07    0.001859
# 1        276351.0       etc  5.356498e-08    0.037402
# 2        321617.0       etc  2.678249e-05    0.031698
# 3        331947.0       etc  2.678249e-07    0.000103
# 4        197911.0       etc  1.339125e-05    0.013231

# %%
temp.groupby('source_acc_id')['item_price'].sum()
# Out:
# source_acc_id
# 2.0          7.426084
# 3.0          0.718069
# 6.0          0.122860
# 8.0          0.064467
# 10.0         0.005948
# 11.0         0.231026
# 17.0         6.655042
# 18.0         1.397254
# 19.0         1.241447
# 20.0        16.743986
# 21.0         0.836389
# 22.0         0.426234
# 26.0         1.907977
# 27.0         0.003899
# 28.0         2.247430
# 30.0         1.495532
# 31.0         0.453557
# 33.0         0.011097
# 34.0         0.351478
# 36.0         0.133987
# 44.0         0.630185
# 45.0         0.032529
# 48.0         0.140897
# 50.0         1.588254
# 53.0         2.598125
# 58.0         4.987732
# 59.0        12.409197
# 61.0         0.052195
# 62.0         0.016433
# 63.0         4.073569
#               ...
# 130405.0     0.347552
# 130410.0     0.071770
# 130411.0     0.051538
# 130412.0     0.044987
# 130414.0     0.337479
# 130415.0     1.291618
# 130416.0    39.175783
# 130418.0    31.136620
# 130423.0     2.310509
# 130424.0     1.001431
# ...

# %%
import datetime

# %%
temp['day'] = pd.to_datetime(temp['day'],format='0000-00-%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'float'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-cf3158ae0f36> in <module>
# ----> 1 temp['day'] = pd.to_datetime(temp['day'],format='0000-00-%d')
#
# ...

# %%
temp.duplicated()
# Out:
# 0          False
# 4          False
# 5          False
# 8          False
# 9          False
# 10         False
# 12         False
# 16         False
# 18         False
# 19         False
# 20         False
# 21         False
# 23         False
# 25         False
# 26         False
# 30         False
# 31         False
# 32         False
# 37         False
# 39         False
# 47         False
# 50         False
# 52         False
# 53         False
# 58         False
# 59         False
# 60         False
# 61         False
# 62         False
# 63         False
#            ...
# 2245157    False
# 2245159    False
# 2245160    False
# 2245161    False
# 2245162    False
# 2245163    False
# 2245164    False
# 2245166    False
# 2245167    False
# 2245169    False
# 2245170    False
# 2245172    False
# 2245173    False
# 2245174    False
# 2245175    False
# 2245176    False
# 2245178    False
# 2245179    False
# 2245180    False
# 2245181    False
# 2245182    False
# ...

# %%
temp.loc[temp.duplicated()]
# Out:
# Empty DataFrame
# Columns: [day, time, type, server, source_acc_id, source_char_id, target_acc_id, target_char_id, item_type, item_amount, item_price]
# Index: []

# %%
temp.head()
# Out:
#    day      time  type server  source_acc_id  source_char_id  target_acc_id  \
# 0  1.0  21:40:09   0.0     bd       115641.0        202802.0        42143.0
# 4  1.0  20:32:00   0.0     ay        50284.0         44100.0        17523.0
# 5  1.0  00:29:02   0.0     ac        87962.0        334455.0        89597.0
# 8  1.0  01:01:32   0.0     ar         5669.0         36002.0        80878.0
# 9  1.0  20:20:02   0.0     aa        54445.0        383477.0        97930.0
#
#    target_char_id item_type   item_amount  item_price
# 0        197398.0       etc  2.678249e-07    0.001859
# 4        276351.0       etc  5.356498e-08    0.037402
# 5        321617.0       etc  2.678249e-05    0.031698
# 8        331947.0       etc  2.678249e-07    0.000103
# 9        197911.0       etc  1.339125e-05    0.013231

# %%
trade_type0_count = temp.groupby('source_acc_id')['source_char_id'].count()

# %%
trade_type0_count
# Out:
# source_acc_id
# 2.0          23
# 3.0          15
# 6.0           8
# 8.0           2
# 10.0          5
# 11.0          1
# 17.0         27
# 18.0         44
# 19.0         11
# 20.0         20
# 21.0          5
# 22.0          8
# 26.0          9
# 27.0          2
# 28.0          7
# 30.0          4
# 31.0          2
# 33.0         25
# 34.0         18
# 36.0          2
# 44.0          4
# 45.0          2
# 48.0          1
# 50.0         57
# 53.0         59
# 58.0         14
# 59.0        132
# 61.0          1
# 62.0          4
# 63.0         24
#            ...
# 130405.0      6
# 130410.0      1
# 130411.0      1
# 130412.0      5
# 130414.0     15
# 130415.0     15
# 130416.0    302
# 130418.0    136
# 130423.0     30
# 130424.0      4
# 130426.0      6
# 130427.0      5
# 130428.0      4
# 130432.0      9
# 130434.0     87
# 130444.0      3
# 130445.0     30
# 130446.0     10
# 130449.0      7
# 130450.0      5
# 130456.0      4
# 130459.0     73
# 130466.0     13
# ...

# %%
temp['source_acc_id'].loc[temp['source_acc_id']==2]
# Out:
# 10156      2.0
# 48190      2.0
# 49630      2.0
# 61554      2.0
# 73152      2.0
# 77868      2.0
# 130194     2.0
# 297788     2.0
# 445694     2.0
# 568758     2.0
# 740506     2.0
# 819653     2.0
# 826546     2.0
# 974347     2.0
# 1046094    2.0
# 1276092    2.0
# 1295212    2.0
# 1330846    2.0
# 1360239    2.0
# 1545180    2.0
# 1622320    2.0
# 1713350    2.0
# 1837756    2.0
# Name: source_acc_id, dtype: float64

# %%
trade_type0_count.index.astype('int32')
# Out:
# Int64Index([     2,      3,      6,      8,     10,     11,     17,     18,
#                 19,     20,
#             ...
#             130456, 130459, 130466, 130468, 130469, 130470, 130471, 130472,
#             130473, 130474],
#            dtype='int64', name='source_acc_id', length=56738)

# %%
trade_type0_count
# Out:
# source_acc_id
# 2.0          23
# 3.0          15
# 6.0           8
# 8.0           2
# 10.0          5
# 11.0          1
# 17.0         27
# 18.0         44
# 19.0         11
# 20.0         20
# 21.0          5
# 22.0          8
# 26.0          9
# 27.0          2
# 28.0          7
# 30.0          4
# 31.0          2
# 33.0         25
# 34.0         18
# 36.0          2
# 44.0          4
# 45.0          2
# 48.0          1
# 50.0         57
# 53.0         59
# 58.0         14
# 59.0        132
# 61.0          1
# 62.0          4
# 63.0         24
#            ...
# 130405.0      6
# 130410.0      1
# 130411.0      1
# 130412.0      5
# 130414.0     15
# 130415.0     15
# 130416.0    302
# 130418.0    136
# 130423.0     30
# 130424.0      4
# 130426.0      6
# 130427.0      5
# 130428.0      4
# 130432.0      9
# 130434.0     87
# 130444.0      3
# 130445.0     30
# 130446.0     10
# 130449.0      7
# 130450.0      5
# 130456.0      4
# 130459.0     73
# 130466.0     13
# ...

# %%
trade_type0_price = temp.groupby('source_acc_id')['item_price'].sum()

# %%
trade_type0_price
# Out:
# source_acc_id
# 2.0          7.426084
# 3.0          0.718069
# 6.0          0.122860
# 8.0          0.064467
# 10.0         0.005948
# 11.0         0.231026
# 17.0         6.655042
# 18.0         1.397254
# 19.0         1.241447
# 20.0        16.743986
# 21.0         0.836389
# 22.0         0.426234
# 26.0         1.907977
# 27.0         0.003899
# 28.0         2.247430
# 30.0         1.495532
# 31.0         0.453557
# 33.0         0.011097
# 34.0         0.351478
# 36.0         0.133987
# 44.0         0.630185
# 45.0         0.032529
# 48.0         0.140897
# 50.0         1.588254
# 53.0         2.598125
# 58.0         4.987732
# 59.0        12.409197
# 61.0         0.052195
# 62.0         0.016433
# 63.0         4.073569
#               ...
# 130405.0     0.347552
# 130410.0     0.071770
# 130411.0     0.051538
# 130412.0     0.044987
# 130414.0     0.337479
# 130415.0     1.291618
# 130416.0    39.175783
# 130418.0    31.136620
# 130423.0     2.310509
# 130424.0     1.001431
# ...

# %%
temp.groupby('server')['item_price'].sum()
# Out:
# server
# aa    10061.835534
# ab    10930.941815
# ac     8926.655791
# ad    10632.081112
# ae     6254.409656
# af     5573.219191
# ag     7530.476442
# ah     3209.962964
# ai     6374.343594
# aj     4002.146191
# ak     4702.906878
# al     7630.701203
# am     8308.343056
# an    17780.795401
# ao     6741.544300
# ap     6100.928369
# aq     5236.236100
# ar    27531.846532
# as     8919.090514
# at     9196.644737
# au     7937.131443
# av     6348.214740
# aw     4373.194801
# ax     8510.863623
# ay    13222.459880
# az     7964.592460
# bb     1643.322874
# bc     2192.198310
# bd     3098.957552
# bg     3102.121180
# bs       22.056335
# Name: item_price, dtype: float64

# %%
temp.groupby('server')['source_acc_id'].unique()[30].size
# Out:
# 23

# %%
ser = pd.DataFrame(temp[['server','source_acc_id']])

# %%
ser.drop_duplicates(inplace=True)

# %%
서버에서거래한아이디수 = ser.groupby('server')['source_acc_id'].count()

# %%
서버에서거래한아이디수
# Out:
# server
# aa    2069
# ab    2335
# ac    1882
# ad    2406
# ae    1780
# af    1490
# ag    1796
# ah    1108
# ai    1755
# aj    1168
# ak    1397
# al    1909
# am    1960
# an    2638
# ao    1491
# ap    1441
# aq    1545
# ar    3221
# as    2306
# at    2328
# au    1908
# av    1710
# aw    1228
# ax    1875
# ay    3756
# az    2959
# bb    1321
# bc    1790
# bd    9204
# bg     811
# bs      23
# Name: source_acc_id, dtype: int64
