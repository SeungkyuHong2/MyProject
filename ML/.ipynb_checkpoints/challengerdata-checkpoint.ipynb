# %%
import pandas as pd
import numpy as np
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Seung kyu Hong\MyProject\ML

# %%
p1 = pd.read_csv('Riot/p1.csv')
p2 = pd.read_csv('Riot/p2.csv')
p3 = pd.read_csv('Riot/p3.csv')
p4 = pd.read_csv('Riot/p4.csv')
p5 = pd.read_csv('Riot/p5.csv')
p6 = pd.read_csv('Riot/p6.csv')
p7 = pd.read_csv('Riot/p7.csv')
p8 = pd.read_csv('Riot/p8.csv')
p9 = pd.read_csv('Riot/p9.csv')
p10 = pd.read_csv('Riot/p10.csv')
t1 = pd.read_csv('Riot/t1.csv')
t2 = pd.read_csv('Riot/t2.csv')
t3 = pd.read_csv('Riot/t3.csv')
t4 = pd.read_csv('Riot/t4.csv')
t5 = pd.read_csv('Riot/t5.csv')
t6 = pd.read_csv('Riot/t6.csv')
t7 = pd.read_csv('Riot/t7.csv')
t8 = pd.read_csv('Riot/t8.csv')
t9 = pd.read_csv('Riot/t9.csv')
t10 = pd.read_csv('Riot/t10.csv')
duration = pd.read_csv('Riot/gameDuration.csv')

# %%
g1 = pd.concat([p1,t1],axis=1)
g2 = pd.concat([p2,t2],axis=1)
g3 = pd.concat([p3,t3],axis=1)
g4 = pd.concat([p4,t4],axis=1)
g5 = pd.concat([p5,t5],axis=1)
g6 = pd.concat([p6,t6],axis=1)
g7 = pd.concat([p7,t7],axis=1)
g8 = pd.concat([p8,t8],axis=1)
g9 = pd.concat([p9,t9],axis=1)
g10 = pd.concat([p10,t10],axis=1)
game = pd.concat([duration,t1['lane']],axis=1)

# %%
g1 = g1[g1['lane']!='NONE']
g2 = g2[g2['lane']!='NONE']
g3 = g3[g3['lane']!='NONE']
g4 = g4[g4['lane']!='NONE']
g5 = g5[g5['lane']!='NONE']
g6 = g6[g6['lane']!='NONE']
g7 = g7[g7['lane']!='NONE']
g8 = g8[g8['lane']!='NONE']
g9 = g9[g9['lane']!='NONE']
g10 = g10[g10['lane']!='NONE']
game = game[game['lane']!='NONE']

# %%
g1.head()
# Out:
#    assists  champLevel  combatPlayerScore  damageDealtToObjectives  \
# 0        7          14                  0                    10525
# 1        5          13                  0                    16214
# 2        9          16                  0                     4484
# 4        8          16                  0                    15925
# 5        9          14                  0                     5093
#
#    damageDealtToTurrets  damageSelfMitigated  deaths  doubleKills  \
# 0                  4029                 6909       2            0
# 1                     0                11365       8            2
# 2                  1305                11263       7            1
# 4                  4007                35269       4            1
# 5                  1141                 9267       8            0
#
#   firstBloodAssist firstBloodKill firstInhibitorAssist firstInhibitorKill  \
# 0            False           True                  NaN                NaN
# ...

# %%
# Out:
# 'BOTTOM'

# %%
pd.set_option('display.max_columns', 135)

# %%
# Out:
# 'MIDDLE'

# %%
# Out:
# 'MIDDLE'
